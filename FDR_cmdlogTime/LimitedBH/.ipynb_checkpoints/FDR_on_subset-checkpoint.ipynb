# %%
import pandas as pd
import numpy as np
from statsmodels.stats import multitest
FN_GENES_OF_INTEREST = "genesOfInterest.txt"
FN_GENES_OF_INTEREST_REDUCED = "genesOfInterestReduced.txt"
DESEQ2_RESULTS = "rnd.deSeq2.noNA.tsv"

# %%
with open (FN_GENES_OF_INTEREST, 'r') as f:
    genes_of_interest = [line.strip() for line in f][1:]
df = pd.read_csv(DESEQ2_RESULTS, sep="\t", index_col=0)
df['fdr'] = multitest.multipletests(df['pval'].to_numpy(), method='fdr_bh')[1]
df.to_csv('rnd.deSeq2_fdr.tsv', sep='\t')
goi_subset = [g for g in genes_of_interest if g in df.index]
df_goi = df.loc[goi_subset,:]

# %%
#type (df_goi['pval'])
df_goi['fdr'] = multitest.multipletests(df_goi['pval'].to_numpy(), method='fdr_bh')[1]
df_goi.head()
df_goi.to_csv('rnd.deSeq2_fdr_goi.tsv', sep='\t')
df_goi
# Out:
#            baseMn  l2fc  lfcSE    stat    pval  padj       fdr
# gene_id
# ACTA2       65.30  0.13   0.18  0.7520  0.4520   1.0  0.959289
# TXLNA      703.00 -0.09   0.09 -0.9950  0.3200   1.0  0.959289
# ACE2         3.41  1.05   0.58  1.8200  0.0689   1.0  0.959289
# APOM         1.22  1.98   1.58  1.2600  0.2090   1.0  0.959289
# TXLNG      196.00 -0.04   0.10 -0.4410  0.6590   1.0  0.959289
# ...           ...   ...    ...     ...     ...   ...       ...
# VCAM1        8.70 -0.03   0.53 -0.0473  0.9620   1.0  0.983000
# VEGFA      242.00  0.04   0.16  0.2650  0.7910   1.0  0.959289
# KDR      23100.00  0.03   0.08  0.3820  0.7020   1.0  0.959289
# VIM      13700.00  0.03   0.10  0.3090  0.7570   1.0  0.959289
# VWF       1390.00  0.01   0.10  0.0629  0.9500   1.0  0.983000
#
# [87 rows x 7 columns]

# %%
with open (FN_GENES_OF_INTEREST_REDUCED, 'r') as f:
    genes_of_interest_reduced = [line.strip() for line in f][1:]
goir_subset = [g for g in genes_of_interest_reduced if g in df.index]
df_goir = df.loc[goir_subset,:]

# %%
df_goir['fdr'] = multitest.multipletests(df_goir['pval'].to_numpy(), method='fdr_bh')[1]
df_goir.to_csv('rnd.deSeq2_fdr_goir.tsv', sep='\t')
df_goir
# Out:
#             baseMn  l2fc  lfcSE    stat    pval  padj      fdr
# gene_id
# CDH2      1440.000  0.21   0.14  1.5100  0.1310   1.0  0.95532
# CDH5      2600.000 -0.02   0.08 -0.3120  0.7550   1.0  0.95532
# CCL13        0.512  2.49   2.63  0.9490  0.3430   1.0  0.95532
# CCL2       167.000  0.15   0.21  0.7430  0.4580   1.0  0.95532
# CCL20       11.400 -0.01   0.40 -0.0246  0.9800   1.0  0.98000
# CCL28        3.010 -0.75   0.74 -1.0100  0.3140   1.0  0.95532
# CCL4         0.417  1.24   1.97  0.6300  0.5290   1.0  0.95532
# CCL7         2.600  0.17   0.71  0.2380  0.8120   1.0  0.95532
# CCL8         7.550  0.45   0.50  0.9030  0.3670   1.0  0.95532
# CXCL1       68.600 -0.08   0.28 -0.2810  0.7790   1.0  0.95532
# CXCL10       2.750  0.28   0.70  0.4100  0.6820   1.0  0.95532
# CXCL11       1.090  0.73   1.14  0.6400  0.5220   1.0  0.95532
# CXCL5      125.000  0.03   0.21  0.1400  0.8890   1.0  0.98000
# CXCL6        0.473  0.83   1.78  0.4650  0.6420   1.0  0.95532
# EDN1       499.000  0.04   0.12  0.3280  0.7430   1.0  0.95532
# SELE      9810.000  0.04   0.13  0.3060  0.7600   1.0  0.95532
# ICAM1      435.000  0.08   0.20  0.4000  0.6890   1.0  0.95532
# ICAM2      172.000 -0.08   0.14 -0.5730  0.5670   1.0  0.95532
# ICAM3       46.100 -0.01   0.17 -0.0435  0.9650   1.0  0.98000
# INHBA       41.800  0.15   0.30  0.4900  0.6240   1.0  0.95532
# IL1A        20.200  0.21   0.24  0.8620  0.3890   1.0  0.95532
# IL1B        16.000 -0.15   0.31 -0.4680  0.6400   1.0  0.95532
# IL10         2.530  0.98   0.86  1.1400  0.2530   1.0  0.95532
# IL15         3.390 -0.41   0.58 -0.7170  0.4730   1.0  0.95532
# IL16       116.000  0.04   0.17  0.2100  0.8330   1.0  0.95532
# IL18         0.454  0.95   1.76  0.5400  0.5890   1.0  0.95532
# IL32       215.000  0.01   0.28  0.0350  0.9720   1.0  0.98000
# IL33       162.000  0.01   0.13  0.0961  0.9230   1.0  0.98000
# IL34         2.770 -0.42   0.91 -0.4650  0.6420   1.0  0.95532
# IL7          0.450  1.26   1.94  0.6530  0.5130   1.0  0.95532
# CXCL8       22.200  0.16   0.39  0.4260  0.6700   1.0  0.95532
# IL1RAP     282.000  0.08   0.08  1.0900  0.2760   1.0  0.95532
# IL1R1      638.000  0.03   0.09  0.3300  0.7420   1.0  0.95532
# IL1RL1      95.000  0.21   0.44  0.4850  0.6270   1.0  0.95532
# IL17RA     461.000 -0.05   0.10 -0.4860  0.6270   1.0  0.95532
# IL13RA1   1610.000  0.03   0.06  0.4810  0.6310   1.0  0.95532
# IL18R1     492.000  0.22   0.11  1.9800  0.0478   1.0  0.95532
# F11R      4150.000  0.16   0.12  1.4000  0.1620   1.0  0.95532
# MMP1      1970.000 -0.06   0.14 -0.4110  0.6810   1.0  0.95532
# MMP14     4230.000 -0.03   0.09 -0.3270  0.7440   1.0  0.95532
# MMP9      1320.000  0.12   0.13  0.9440  0.3450   1.0  0.95532
# NOS3       425.000  0.06   0.16  0.3540  0.7240   1.0  0.95532
# PECAM1    9930.000 -0.01   0.07 -0.2050  0.8380   1.0  0.95532
# TGFA         7.670  0.67   0.43  1.5600  0.1190   1.0  0.95532
# SELP        52.100  0.08   0.16  0.4940  0.6210   1.0  0.95532
# TLR2        14.600  0.10   0.26  0.3830  0.7020   1.0  0.95532
# TLR9         0.480 -1.49   1.59 -0.9420  0.3460   1.0  0.95532
# TGFB1     1950.000 -0.02   0.11 -0.2180  0.8270   1.0  0.95532
# TGFBR1     719.000  0.12   0.13  0.9010  0.3680   1.0  0.95532
# TNF          0.632 -1.43   1.34 -1.0700  0.2860   1.0  0.95532
# TNFSF10     71.200 -0.21   0.21 -0.9700  0.3320   1.0  0.95532
# TNFSF12     52.200  0.18   0.22  0.8000  0.4230   1.0  0.95532
# TNFSF14      1.640 -1.19   0.85 -1.4000  0.1630   1.0  0.95532
# VCAM1        8.700 -0.03   0.53 -0.0473  0.9620   1.0  0.98000
# VEGFA      242.000  0.04   0.16  0.2650  0.7910   1.0  0.95532
# KDR      23100.000  0.03   0.08  0.3820  0.7020   1.0  0.95532
# VWF       1390.000  0.01   0.10  0.0629  0.9500   1.0  0.98000
